# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hotel=pd.read_csv("hotel_bookings 2.csv")

# %%
hotel
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
hotel.shape
# Out:
# (119390, 32)

# %%
hotel.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel.tail(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
hotel.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
hotel.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
hotel.columns.values
# Out:
# array(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'], dtype=object)

# %%
data=hotel.copy()
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
data["country"]=data['country'].fillna('Ind')

# %%
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                                0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
data.drop(['company'],axis=1,inplace=True)

# %%
data['agent']=data['agent'].ffill()

# %%
data['children']=data['children'].bfill()

# %%
data['agent']=data['agent'].fillna(data['agent'].mean())

# %%
data.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
data['country'].value_counts().get('ESP')
# Out:
# np.int64(8568)

# %%
data['country'].value_counts()
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# MRT        1
# KIR        1
# SDN        1
# ATF        1
# SLE        1
# Name: count, Length: 178, dtype: int64

# %%
data['reservation_status_date'].value_counts()
# Out:
# reservation_status_date
# 21/10/2015    1461
# 6/7/2015       805
# 25/11/2016     790
# 1/1/2015       763
# 18/1/2016      625
#               ...
# 30/4/2015        1
# 13/3/2015        1
# 29/3/2015        1
# 27/4/2015        1
# 10/3/2015        1
# Name: count, Length: 926, dtype: int64

# %%
data['adults'].value_counts()
# Out:
# adults
# 2     89680
# 1     23027
# 3      6202
# 0       403
# 4        62
# 26        5
# 5         2
# 27        2
# 20        2
# 40        1
# 55        1
# 50        1
# 6         1
# 10        1
# Name: count, dtype: int64

# %%
len(data['reservation_status_date'].unique())
# Out:
# 926

# %%
data['distribution_channel'].value_counts()
# Out:
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64

# %%
data['arrival_date_day_of_month'].value_counts()
# Out:
# arrival_date_day_of_month
# 17    4406
# 5     4317
# 15    4196
# 25    4160
# 26    4147
# 9     4096
# 12    4087
# 16    4078
# 2     4055
# 19    4052
# 20    4032
# 18    4002
# 24    3993
# 28    3946
# 8     3921
# 3     3855
# 30    3853
# 6     3833
# 14    3819
# 27    3802
# 21    3767
# 4     3763
# 13    3745
# 7     3665
# 1     3626
# 23    3616
# 11    3599
# 22    3596
# 29    3580
# 10    3575
# 31    2208
# Name: count, dtype: int64

# %%
data.iloc[1:10,1:6]
# Out:
#    is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 1            0        737               2015               July
# 2            0          7               2015               July
# 3            0         13               2015               July
# 4            0         14               2015               July
# 5            0         14               2015               July
# 6            0          0               2015               July
# 7            0          9               2015               July
# 8            1         85               2015               July
# 9            1         75               2015               July
#
#    arrival_date_week_number
# 1                        27
# 2                        27
# 3                        27
# 4                        27
# 5                        27
# 6                        27
# 7                        27
# 8                        27
# 9                        27

# %%
data.loc[[1000,500]]
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 1000  Resort Hotel            0         72               2015
# 500   Resort Hotel            0         13               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 1000             August                        33                          9
# 500                July                        29                         17
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 1000                        2                     5       2  ...
# 500                         1                     2       2  ...
#
#       booking_changes  deposit_type  agent days_in_waiting_list customer_type  \
# 1000                0    No Deposit  149.0                    0     Transient
# 500                 0    No Deposit  240.0                    0     Transient
#
#         adr  required_car_parking_spaces  total_of_special_requests  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
data[['hotel','arrival_date_month','stays_in_weekend_nights','customer_type']]
# Out:
#                hotel arrival_date_month  stays_in_weekend_nights customer_type
# 0       Resort Hotel               July                        0     Transient
# 1       Resort Hotel               July                        0     Transient
# 2       Resort Hotel               July                        0     Transient
# 3       Resort Hotel               July                        0     Transient
# 4       Resort Hotel               July                        0     Transient
# ...              ...                ...                      ...           ...
# 119385    City Hotel             August                        2     Transient
# 119386    City Hotel             August                        2     Transient
# 119387    City Hotel             August                        2     Transient
# 119388    City Hotel             August                        2     Transient
# 119389    City Hotel             August                        2     Transient
#
# ...

# %%
data.loc[ :20 ,'children':'agent' ]
# Out:
#     children  babies meal country market_segment distribution_channel  \
# 0        0.0       0   BB     PRT         Direct               Direct
# 1        0.0       0   BB     PRT         Direct               Direct
# 2        0.0       0   BB     GBR         Direct               Direct
# 3        0.0       0   BB     GBR      Corporate            Corporate
# 4        0.0       0   BB     GBR      Online TA                TA/TO
# 5        0.0       0   BB     GBR      Online TA                TA/TO
# 6        0.0       0   BB     PRT         Direct               Direct
# 7        0.0       0   FB     PRT         Direct               Direct
# 8        0.0       0   BB     PRT      Online TA                TA/TO
# 9        0.0       0   HB     PRT  Offline TA/TO                TA/TO
# 10       0.0       0   BB     PRT      Online TA                TA/TO
# 11       0.0       0   HB     PRT      Online TA                TA/TO
# ...

# %%
A=sns.countplot(x='hotel',data=data,palette='husl',legend=False,hue='hotel')
for i in A.containers:
    A.bar_label(i)
plt.show()

# %%
plt.figure(figsize=(10,5))
B=sns.countplot(x='arrival_date_month',data=data,palette='husl',hue='arrival_date_month',legend=False)
for i in B.containers:
    B.bar_label(i)
plt.show()

# %%
plt.figure(figsize=(5,5))
C=sns.countplot(x='is_canceled',data=data,hue='is_canceled',legend=False,palette='husl')
for i in C.containers:
    C.bar_label(i)
plt.show()

# %%
D=sns.countplot(x='reservation_status',data=data,hue='reservation_status',legend=False,palette='husl')
for i in D.containers:
    D.bar_label(i)

# %%
top_countries = data['country'].value_counts().head(20)
plt.figure(figsize=(12,6))
colors = ['red','green','pink','blue','orange','yellow']
bars = sns.barplot(x=top_countries.index,y=top_countries.values)
for i, bar in enumerate(bars.patches):
    bar.set_color(colors[i % len(colors)])
plt.title('Top 10 Countries with Most Reservations')
plt.xlabel('Country')
plt.ylabel('Number of Reservations')
plt.show()

# %%
top_countries = data['country'].value_counts().head(10)
plt.figure(figsize=(12,6))
colors = ['red','green','pink','blue','orange','yellow']
bars = sns.barplot(x=top_countries.index,y=top_countries.values)
for i, bar in enumerate(bars.patches):
    bar.set_color(colors[i % len(colors)])
plt.title('Top 10 Countries with Most Reservations')
plt.xlabel('Country')
plt.ylabel('Number of Reservations')
plt.show()

# %%
for column in data.columns:
    plt.figure(figsize=(12, 5))  
    ax=sns.countplot(data=data, x=column,hue='is_canceled',palette='husl',legend=False)
    plt.title(f'Countplot for {column}')
    plt.show()

# %%
F=sns.countplot(x='adults',data=data,palette='husl',legend=False,hue='adults')
for i in F.containers:
    F.bar_label(i)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='is_canceled', y='lead_time', data=data,palette=['red','green'],legend=False,hue='is_canceled')
plt.title('Lead Time Impact on Cancellations')
plt.xlabel('Is Canceled (1 = Canceled, 0 = Not Canceled)')
plt.ylabel('Lead Time (days)')
plt.show()

# %%
sns.barplot( y='total_of_special_requests',hue='is_canceled',data=data,palette='Blues')
plt.show()

# %%
sns.countplot(x='reservation_status',hue='is_canceled',data=data,palette='Blues')
plt.show()

# %%
sns.scatterplot(x='hotel',y='reservation_status',data=data)
plt.show()

# %%
sns.countplot(x='hotel',hue='is_canceled',data=data,palette='Blues')
plt.show()

# %%
sns.countplot(x='is_canceled',hue='hotel',data=data,palette='Oranges')
# Out:
# <Axes: xlabel='is_canceled', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='reservation_status_date',y='adr',hue='hotel',data=data)
# Out:
# <Axes: xlabel='reservation_status_date', ylabel='adr'>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='arrival_date_year',y='adr',hue='hotel',data=data)
# Out:
# <Axes: xlabel='arrival_date_year', ylabel='adr'>

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x='arrival_date_month',y='adr',hue='hotel',data=data)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x='arrival_date_week_number',y='adr',hue='hotel',data=data)
plt.show()

# %%
sns.histplot(x='hotel',data=data,kde=True)
# Out:
# <Axes: xlabel='hotel', ylabel='Count'>

# %%
plt.figure(figsize=(7,5))
ax = sns.barplot(x='hotel',y='adr',hue='is_canceled',data=data)
for container in ax.containers:
    ax.bar_label(container)

# %%
sns.barplot(x='hotel',y='adr',hue='is_repeated_guest',data=data)
plt.show()

# %%
plt.figure(figsize=(12,5))
ax = sns.barplot(x='arrival_date_month',y='adr',data=data,legend=False,hue='arrival_date_month')
for container in ax.containers:
    ax.bar_label(container)

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='arrival_date_month', hue='is_canceled', data=data)
plt.title('Cancellations by Month')
plt.xlabel('Month')
plt.ylabel('Number of Reservations')
plt.legend(title='Is Canceled')
plt.show()

# %%
plt.figure(figsize=(14,8))
ax = sns.barplot(x='arrival_date_month',y='adr',hue='is_canceled',data=data)
for container in ax.containers:
    ax.bar_label(container)

# %%
plt.figure(figsize=(14,8))
ax = sns.barplot(x='arrival_date_month',y='adr',hue='is_repeated_guest',data=data)
for container in ax.containers:
    ax.bar_label(container)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='arrival_date_year',y='adr',data=data[data['is_canceled']==1].groupby('arrival_date_year')['adr'].sum().reset_index(),palette=['red','green','yellow'],legend=False,hue='arrival_date_year')
plt.show()

# %%
plt.figure(figsize=(12,8))
bx=sns.barplot(x='arrival_date_month',y='adr',palette='husl',hue='arrival_date_month',legend=False,data=data[data['is_canceled']==1].groupby('arrival_date_month')['adr'].sum().reset_index())
for i in bx.containers:
    bx.bar_label(i)
    plt.show()

# %%
plt.figure(figsize=(12,8))
a=sns.barplot(x='market_segment',y='adr',palette='husl',hue='market_segment',legend=False,data=data[data['is_canceled']==1].groupby('market_segment')['adr'].sum().reset_index())
for i in a.containers:
    a.bar_label(i)
    plt.show()

# %%
data['country']
# Out:
# 0         PRT
# 1         PRT
# 2         GBR
# 3         GBR
# 4         GBR
#          ...
# 119385    BEL
# 119386    FRA
# 119387    DEU
# 119388    GBR
# 119389    DEU
# Name: country, Length: 119390, dtype: object

# %%
county = data['country'].value_counts().head(10)
labels = ['PRT', 'GBR', 'USA', 'ESP', 'IRL', 'FRA', 'ITA', 'ROU', 'NOR', 'OMN']  # Corrected variable name
plt.figure(figsize=(12, 12))
plt.pie(county, labels=labels, autopct='%2.1f%%', startangle=90)
plt.show()

# %%
b = data[data['is_canceled']==1]
county = b['country'].value_counts().head(5)
plt.figure(figsize=(10,10))
plt.pie(county,labels=county ,autopct='%2.1f%%',startangle=90)
plt.show()

# %%
hotel= data.select_dtypes(include=[int, float])

# %%
hotel
# Out:
#         is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 0                 0        342               2015                        27
# 1                 0        737               2015                        27
# 2                 0          7               2015                        27
# 3                 0         13               2015                        27
# 4                 0         14               2015                        27
# ...             ...        ...                ...                       ...
# 119385            0         23               2017                        35
# 119386            0        102               2017                        35
# 119387            0         34               2017                        35
# 119388            0        109               2017                        35
# 119389            0        205               2017                        35
#
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(hotel.corr(),annot=True)
plt.show()
